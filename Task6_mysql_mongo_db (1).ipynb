# %%
'''Mysql : 
    
    1. Create a  table attribute dataset and dress dataset
    2. Do a bulk load for these two table for respective dataset 
    3. read these dataset in pandas as a dataframe 
    4. Convert attribute dataset in json format 
    5. Store this dataset into mongodb
    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
    7. Write a sql query to find out how many unique dress that we have based on dress id 
    8. Try to find out how mnay dress is having recommendation 0
    9. Try to find out total dress sell for individual dress id 
    10. Try to find out a third highest most selling dress id '''
# Out:
# 'Mysql : \n    \n    1. Create a  table attribute dataset and dress dataset\n    2. Do a bulk load for these two table for respective dataset \n    3. read these dataset in pandas as a dataframe \n    4. Convert attribute dataset in json format \n    5. Store this dataset into mongodb\n    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID\n    7. Write a sql query to find out how many unique dress that we have based on dress id \n    8. Try to find out how mnay dress is having recommendation 0\n    9. Try to find out total dress sell for individual dress id \n    10. Try to find out a third highest most selling dress id '

# %%
import pandas as pd     #to load data into dataframe and for some data manupilations import pandas
import sqlalchemy       #this is the library that facilitates the comunication between python programs and databases
import pymysql          #this is an interface to connect mysql database server feom python

# %%
df_att = pd.read_csv(r"C:\Program Files\MySQL\MySQL Workbench 8.0\Attribute DataSet1.csv")  #reading dataset into dataframe

# %%
df_att.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df_att.fillna("-",inplace=True)     #this will drop the null values and replace with " - "

# %%
df_att.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire              -    chiffon     ruffles       animal               1
# 1   natural     microfiber          -     ruffles       animal               0
# 2   natural       polyster          -           -        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:12345@localhost:3306/ineuron')   #connection with msql from python

# %%
df_att.to_sql(con=engine,name='attribute_dataset',if_exists="append",index=False)     #inserting dataset to mysql_db from python

# %%
df_dress = pd.read_csv(r"C:\Users\Shivanand\Documents\Dress Sales_1.csv")    #another dataset to dataframe

# %%
df_dress.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852       2114       2274        2491        2660        2727
# 1  1212192089        151        275         570         750         813
# 2  1190380701          6          7           7           7           8
# 3   966005983       1005       1128        1326        1455        1507
# 4   876339541        996       1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14/9/2013  ... Unnamed: 26 Unnamed: 27  \
# 0        2887        2930       3119      3204  ...         NaN         NaN
# 1        1066        1164       1558      1756  ...         NaN         NaN
# 2           8           9         10        10  ...         NaN         NaN
# 3        1621        1637       1723      1746  ...         NaN         NaN
# 4        1559        1570       1638      1655  ...         NaN         NaN
#
# ...

# %%
df_dress.dropna(axis=1,inplace=True)    #this will drop all the useless null or blank columns

# %%
df_dress.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852       2114       2274        2491        2660        2727
# 1  1212192089        151        275         570         750         813
# 2  1190380701          6          7           7           7           8
# 3   966005983       1005       1128        1326        1455        1507
# 4   876339541        996       1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14/9/2013 16/9/2013 18/9/2013 20/9/2013  \
# 0        2887        2930       3119      3204      3277      3321      3386
# 1        1066        1164       1558      1756      1878      1985      2106
# 2           8           9         10        10        10        10        10
# 3        1621        1637       1723      1746      1783      1796      1812
# 4        1559        1570       1638      1655      1681      1743      1824
#
#   22/9/2013  24/9/2013  28/9/2013  10-06-2013  10-12-2013
# ...

# %%
df_dress.fillna("-",inplace=True)

# %%
df_dress.head(10)
# Out:
#      Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852       2114       2274        2491        2660        2727
# 1  1212192089        151        275         570         750         813
# 2  1190380701          6          7           7           7           8
# 3   966005983       1005       1128        1326        1455        1507
# 4   876339541        996       1175        1304        1396        1432
# 5  1068332458          4          5          11          13          13
# 6  1220707172         45         61         131         165         176
# 7  1219677488          4         13          55          73          76
# 8  1113094204          5          6          10          12          13
# 9   985292672          9         11          12          12          12
#
#    09-08-2013  09-10-2013 09-12-2013 14/9/2013 16/9/2013 18/9/2013 20/9/2013  \
# 0        2887        2930       3119      3204      3277      3321      3386
# ...

# %%
df_dress.tail()
# Out:
#       Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 495  713391965          0          0           0         560         554
# 496  722565148          0          0           0         875         866
# 497  532874347          0          0           0         734         728
# 498  655464934          0          0           0         254         259
# 499  919930954          0          0           0         538         545
#
#      09-08-2013  09-10-2013 09-12-2013 14/9/2013 16/9/2013 18/9/2013  \
# 495         544         537        525       519       511       501
# 496         861         854        850       844       841       845
# 497         726         715        694       690       686       674
# 498         261         263        268       270       272       272
# 499         558         563        578       585       590       599
#
#     20/9/2013 22/9/2013  24/9/2013  28/9/2013  10-06-2013  10-12-2013
# ...

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:12345@localhost:3306/ineuron')   #connection with mysql from python

# %%
df_dress.to_sql(con=engine,name='dress_dataset',if_exists="append",index=False)   #inserting dataset to mysql_db from python

# %%
#converting attribute_dataset to json format
df = pd.read_csv(r"C:\Program Files\MySQL\MySQL Workbench 8.0\Attribute DataSet1.csv")

# %%
json_data = df.to_dict(orient = "records")

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://Aadisheshu_Bairy:Ineuron.ai@cluster0.ua6zshk.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
database=client['myinfo']
collection=database["aadi"]
collection.insert_many(json_data)

# %%
import mysql.connector as connection

mydb=connection.connect(host="localhost",user="root",passwd="12345")

cursor=mydb.cursor()

# %%
cursor.execute("use ineuron")

# %%
cursor.execute("select attribute_dataset.Dress_ID from attribute_dataset left join dress_dataset on attribute_dataset.Dress_ID = dress_dataset.Dress_ID")
cursor.fetchall()
# Out:
# [(1006032852,),
#  (1006032852,),
#  (1006032852,),
#  (1006032852,),
#  (1212192089,),
#  (1212192089,),
#  (1212192089,),
#  (1212192089,),
#  (1190380701,),
#  (1190380701,),
#  (1190380701,),
#  (1190380701,),
#  (966005983,),
#  (966005983,),
#  (966005983,),
#  (966005983,),
#  (876339541,),
#  (876339541,),
#  (876339541,),
#  (876339541,),
#  (1068332458,),
#  (1068332458,),
#  (1068332458,),
#  (1068332458,),
#  (1220707172,),
#  (1220707172,),
#  (1220707172,),
#  (1220707172,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1219677488,),
#  (1113094204,),
#  (1113094204,),
#  (1113094204,),
#  (1113094204,),
#  (985292672,),
#  (985292672,),
#  (985292672,),
#  (985292672,),
#  (1117293701,),
#  (1117293701,),
#  (1117293701,),
#  (1117293701,),
#  (898481530,),
#  (898481530,),
#  (898481530,),
#  (898481530,),
#  (957723897,),
#  (957723897,),
#  (957723897,),
#  (957723897,),
# ...

# %%
cursor.execute("select distinct Style from attribute_dataset")
cursor.fetchall()
# Out:
# [('Sexy',),
#  ('Casual',),
#  ('vintage',),
#  ('Brief',),
#  ('cute',),
#  ('bohemian',),
#  ('Novelty',),
#  ('Flare',),
#  ('party',),
#  ('work',),
#  ('OL',),
#  ('fashion',)]

# %%
cursor.execute("select distinct FabricType from attribute_dataset")
cursor.fetchall()
# Out:
# [('chiffon',),
#  ('-',),
#  ('broadcloth',),
#  ('jersey',),
#  ('other',),
#  ('batik',),
#  ('satin',),
#  ('flannael',),
#  ('worsted',),
#  ('woolen',),
#  ('poplin',),
#  ('dobby',),
#  ('knitting',),
#  ('flannel',),
#  ('tulle',),
#  ('sattin',),
#  ('organza',),
#  ('lace',),
#  ('Corduroy',),
#  ('wollen',),
#  ('knitted',),
#  ('shiffon',),
#  ('terry',)]

# %%
cursor.execute("select distinct Material from attribute_dataset")
cursor.fetchall()
# Out:
# [('-',),
#  ('microfiber',),
#  ('polyster',),
#  ('silk',),
#  ('chiffonfabric',),
#  ('cotton',),
#  ('nylon',),
#  ('other',),
#  ('milksilk',),
#  ('linen',),
#  ('rayon',),
#  ('lycra',),
#  ('mix',),
#  ('acrylic',),
#  ('spandex',),
#  ('lace',),
#  ('modal',),
#  ('cashmere',),
#  ('viscos',),
#  ('knitting',),
#  ('sill',),
#  ('wool',),
#  ('model',),
#  ('shiffon',)]

# %%
cursor.execute("select distinct SleeveLength from attribute_dataset")
cursor.fetchall()
# Out:
# [('sleevless',),
#  ('Petal',),
#  ('full',),
#  ('butterfly',),
#  ('short',),
#  ('threequarter',),
#  ('halfsleeve',),
#  ('cap-sleeves',),
#  ('turndowncollor',),
#  ('threequater',),
#  ('capsleeves',),
#  ('sleeveless',),
#  ('sleeevless',),
#  ('half',),
#  ('urndowncollor',),
#  ('thressqatar',),
#  ('-',),
#  ('sleveless',)]

# %%
cursor.execute("select distinct NeckLine from attribute_dataset")
cursor.fetchall()
# Out:
# [('o-neck',),
#  ('v-neck',),
#  ('boat-neck',),
#  ('peterpan-collor',),
#  ('ruffled',),
#  ('turndowncollor',),
#  ('slash-neck',),
#  ('mandarin-collor',),
#  ('open',),
#  ('sqare-collor',),
#  ('Sweetheart',),
#  ('-',),
#  ('Scoop',),
#  ('halter',),
#  ('backless',),
#  ('bowneck',)]

# %%
cursor.execute("select distinct Season from attribute_dataset")
cursor.fetchall()
# Out:
# [('Summer',), ('Automn',), ('Spring',), ('Winter',), ('-',), ('Autumn',)]

# %%
cursor.execute("select distinct Size from attribute_dataset")
cursor.fetchall()
# Out:
# [('M',), ('L',), ('XL',), ('free',), ('S',), ('small',)]

# %%
cursor.execute("select distinct Rating from attribute_dataset")
cursor.fetchall()
# Out:
# [(4.6,),
#  (0.0,),
#  (4.5,),
#  (5.0,),
#  (4.7,),
#  (4.8,),
#  (4.3,),
#  (4.0,),
#  (4.4,),
#  (4.9,),
#  (4.2,),
#  (3.6,),
#  (3.7,),
#  (4.1,),
#  (3.5,),
#  (1.0,),
#  (3.0,)]

# %%
cursor.execute("select distinct Price from attribute_dataset")
cursor.fetchall()
# Out:
# [('Low',), ('High',), ('Average',), ('Medium',), ('very-high',), ('-',)]

# %%
cursor.execute("select count(*) from attribute_dataset where Recommendation=0")
cursor.fetchall()
# Out:
# [(1160,)]

# %%
cursor.execute("select count(Dress_ID) from attribute_dataset")
cursor.fetchall()
# Out:
# [(2000,)]

# %%
cursor.execute("select count(Dress_ID) as sold_count from dress_dataset group by Dress_ID order by Dress_ID")
cursor.fetchall()
# Out:
# [(4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (8,),
#  (8,),
#  (8,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
#  (4,),
# ...
